# %% [markdown]
# # 01. ABSA using Bi-LSTM

# %%
import matplotlib.pyplot as plt

# Các giá trị loss đã trích xuất
loss_values = [
    0.35701917280161893, 0.2543433616109942, 0.21643054834136727, 
    0.1879604785747107, 0.16580554699138939, 0.14717986552499893, 
    0.13283996137138265, 0.11881087757111575, 0.10798266530036926, 
    0.09831595127862827, 0.08895349209588901, 0.08093492969778773, 
    0.07498413566461701, 0.06887476303800176, 0.06336844679220624, 
    0.0588150595102528, 0.05458639443180767, 0.04975261287170881, 
    0.04557999273957168, 0.04312661612020075, 0.040897934527367785,
    0.03912197627524943, 0.03235150888959975, 0.029859618230261963, 
    0.029507471235120934, 0.02635333414076688, 0.024805937934804564,
    0.026403492652224015, 0.030596404812572184, 0.020933447399958813,
    0.021102205838709764, 0.01991456458670158, 0.01865543902792358,
    0.017413773166600928, 0.016814415604143845, 0.013912282642684647,
    0.013635942056006321, 0.014922661669514078, 0.01472458113663786, 0.013036285298044585
]

# Số epoch
epochs = list(range(1, len(loss_values) + 1))

# Vẽ biểu đồ
plt.figure(figsize=(13, 6))
plt.plot(epochs, loss_values, marker='o', linestyle='-', color='b')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.grid(True)
plt.show()

# %% [markdown]
# # 02. ABSA using LSTM

# %% [markdown]
# # 03. ABSA using RNN

# %%
import matplotlib.pyplot as plt
rnn_loss = [0.2240360308232004,
0.18419618258975615,
0.1570158595299574,
0.13546707343455458,
0.1184748739493701,
0.10322257653031751,
0.089470876369327,
0.07842894155509174,
0.06938255990585752,
0.061233339991871825,
0.05425387879477879,
0.04787318307133793,
0.04214495317761842,
0.03725947599735654,
0.03333241639188367,
0.03058727961836777,
0.026574214520716937,
0.024818539384224698,
0.022305012746566804,
0.021231128175377662,
0.017935589674929083,
0.017240576302628863,
0.015365779546167878,
0.015259363935223839,
0.014913158280893518,
0.012947742408428348,
0.012019935575097769,
0.011228333066697606,
0.011064438570531762,
0.010730645391761155,
0.008953066096207015,
0.01098942683982898,
0.00846434257842325,
0.0076327395866370665,
0.006874133908291189,
0.009802428269003436,
0.008580139596961836,
0.006624470678592211,
0.007180850200108358,
0.006327896895512434]
# Số epoch
epochs = list(range(1, len(rnn_loss) + 1))

# Vẽ biểu đồ
plt.figure(figsize=(13, 6))
plt.plot(epochs, rnn_loss, marker='o', linestyle='-', color='b')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.grid(True)
plt.show()

# %% [markdown]
# # 04. ABSA using GRU

# %%
gru_loss = [0.23072011462839231,
0.18701695450399936,
0.15728996366690806,
0.13490936134079398,
0.11640188646420561,
0.10072557250271098,
0.08754791470064764,
0.07631127020722787,
0.06634403382345759,
0.05877155634656824,
0.05144381649730999,
0.04509158282171652,
0.041310350527294606,
0.03630267967540748,
0.031870108694450075,
0.02851494640356706,
0.025057866203635013,
0.02266153636593104,
0.020191683438730863,
0.019690822266822477,
0.017744007830181038,
0.018211091171521733,
0.015696002005980002,
0.013910082950078916,
0.012084153729435478,
0.011375633521613644,
0.012339632015376977,
0.011055652909382443,
0.01016641503393084,
0.009478322527652464,
0.009201790407649959,
0.009797658260196478,
0.008422612707184158,
0.008916936133504373,
0.007922052246091976,
0.007596687635347568,
0.007458596049283978,
0.007768735964400063,
0.005990219619211185,
0.00789286472126593,]
import matplotlib.pyplot as plt
# Số epoch
epochs = list(range(1, len(gru_loss) + 1))

# Vẽ biểu đồ
plt.figure(figsize=(13, 6))
plt.plot(epochs, gru_loss, marker='o', linestyle='-', color='b')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.grid(True)
plt.show()

# %% [markdown]
# # ABSA using Transformer

# %%
transformers_loss = [0.20577674743086405,
0.16386461521076226,
0.1376922554977131,
0.11787006332399419,
0.10045619149839609,
0.08614059630207702,
0.07387613082109536,
0.06241546145179433,
0.05378973436995086,
0.04656482695982442,
0.040159203777629,
0.03500819004483108,
0.0319774194565091,
0.02687690035273652,
0.02465150948686552,
0.0215020240772156,
0.02044988508973064,
0.017885497693752667,
0.01542954072470966,
0.014467109064045658,
0.01425108642965647,
0.012866584950813248,
0.010992712745714542,
0.010149839287097862,
0.01301177773381788,
0.011627146703127993,
0.009186577588535876,
0.007379236405436141,
0.008838517870801813,
0.007439410893650041,
0.00756856289874376,
0.00966131428731854,
0.008837714532172226,
0.0065500038776124085,
0.00594910132235922,
0.007008651355606575,
0.008263672805760338,
0.00696349470614163,
0.006614643992909691,
0.007556389504995817,]
import matplotlib.pyplot as plt
# Số epoch
epochs = list(range(1, len(transformers_loss) + 1))

# Vẽ biểu đồ
plt.figure(figsize=(13, 6))
plt.plot(epochs, transformers_loss, marker='o', linestyle='-', color='b')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.grid(True)
plt.show()

# %% [markdown]
# # Vẽ chung một biểu đồ duy nhất

# %%
import matplotlib.pyplot as plt
# Số epoch
epochs = list(range(1, len(transformers_loss) + 1))

# Vẽ biểu đồ
plt.figure(figsize=(13, 6))
plt.plot(epochs, transformers_loss, marker='o', linestyle='-', color='blue', label='Transformer loss')
plt.plot(epochs, gru_loss, marker='o', linestyle='-', color='green', label='GRU loss')
plt.plot(epochs, rnn_loss, marker='o', linestyle='-', color='red', label='RNN loss')
plt.plot(epochs, loss_values, marker='o', linestyle='-', color='black', label='LSTM loss')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.legend()
plt.grid(True)
plt.show()
